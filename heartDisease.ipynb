# %%
import pandas as pd

# %%
# dataset: https://bigcitieshealthdata.org/

df = pd.read_csv('BigCitiesHealth.csv')
data = df[df['metric_item_label']=='Adult Obesity']
data.head()
# Out:
# C:\Users\pih\AppData\Local\Temp\ipykernel_12764\3507335416.py:3: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('BigCitiesHealth.csv')
#       metric_item_label           metric_cat_label   metric_subcat_label  \
# 48183     Adult Obesity  Chronic Health Conditions  Diabetes and Obesity
# 48184     Adult Obesity  Chronic Health Conditions  Diabetes and Obesity
# 48185     Adult Obesity  Chronic Health Conditions  Diabetes and Obesity
# 48186     Adult Obesity  Chronic Health Conditions  Diabetes and Obesity
# 48187     Adult Obesity  Chronic Health Conditions  Diabetes and Obesity
#
#                      metric_item_label_subtitle metric_cat_item_yaxis_label  \
# 48183  Percent of adults aged 18+ who are obese                     Percent
# 48184  Percent of adults aged 18+ who are obese                     Percent
# 48185  Percent of adults aged 18+ who are obese                     Percent
# ...

# %%
# Summary statistics for 'Adult Obesity'
data['metric_item_label'].describe()
# Out:
# count               432
# unique                1
# top       Adult Obesity
# freq                432
# Name: metric_item_label, dtype: object
